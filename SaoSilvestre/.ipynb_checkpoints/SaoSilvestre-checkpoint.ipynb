# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from pprint import pprint
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import RandomizedSearchCV
import pickle
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import statsmodels.api as sm

# %%
df = pd.read_csv("dataset.csv",encoding='cp1252')

# %%
df.head()
# Out:
#     Ano               Mulheres    TempoM  Idade-M   Pais-M            Homens  \
# 0  1991     Maria Luisa Servin  54:02:00       29   Mexico    Arturo Barrios
# 1  1992  Maria Del Carmen Diaz  54:00:00       32   Mexico  Simon Chemwoiywo
# 2  1993         Hellen Kimaiyo  50:26:00       25   Quenia  Simon Chemwoiywo
# 3  1994           Derartu Tulu  51:17:00       22  Etiopia  Ronaldo da Costa
# 4  1995        Carmem Oliveira  50:53:00       30   Brasil       Paul Tergat
#
#      TempoH  Idade-H    Pais-H
# 0  44:47:00       29  Mexicano
# 1  44:08:00       24    Quenia
# 2  43:20:00       25    Quenia
# 3  44:11:00       24    Brasil
# 4  43:12:00       26    Quenia

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 9 columns):
# Ano         28 non-null int64
# Mulheres    28 non-null object
# TempoM      28 non-null object
# Idade-M     28 non-null int64
# Pais-M      28 non-null object
# Homens      28 non-null object
# TempoH      28 non-null object
# Idade-H     28 non-null int64
# Pais-H      28 non-null object
# dtypes: int64(3), object(6)
# memory usage: 2.1+ KB

# %%
df[['hour_TempoM', 'minute_TempoM', 'second_TempoM']] = df['TempoM'].astype(str).str.split(':', expand=True).astype(int)
df[['hour_TempoH', 'minute_TempoH', 'second_TempoH']] = df['TempoH'].astype(str).str.split(':', expand=True).astype(int)

# %%
df.drop(['TempoM','TempoH','second_TempoM','second_TempoH'], axis=1, inplace=True)
df= df.rename(columns={'hour_TempoM': 'minM', 'minute_TempoM': 'segM','hour_TempoH':'minH','minute_TempoH':'segH'} )
df.head()
# Out:
#     Ano               Mulheres  Idade-M   Pais-M            Homens  Idade-H  \
# 0  1991     Maria Luisa Servin       29   Mexico    Arturo Barrios       29
# 1  1992  Maria Del Carmen Diaz       32   Mexico  Simon Chemwoiywo       24
# 2  1993         Hellen Kimaiyo       25   Quenia  Simon Chemwoiywo       25
# 3  1994           Derartu Tulu       22  Etiopia  Ronaldo da Costa       24
# 4  1995        Carmem Oliveira       30   Brasil       Paul Tergat       26
#
#      Pais-H  minM  segM  minH  segH
# 0  Mexicano    54     2    44    47
# 1    Quenia    54     0    44     8
# 2    Quenia    50    26    43    20
# 3    Brasil    51    17    44    11
# 4    Quenia    50    53    43    12

# %%
df['SegM'] = df['minM']*60+df['segM']
df['SegH'] = df['minH']*60+df['segH']
df.drop(['minM','minH','segM','segH'], axis=1, inplace=True)

# %%
df
# Out:
#      Ano                   Mulheres  Idade-M               Pais-M  \
# 0   1991         Maria Luisa Servin       29               Mexico
# 1   1992      Maria Del Carmen Diaz       32               Mexico
# 2   1993             Hellen Kimaiyo       25               Quenia
# 3   1994               Derartu Tulu       22              Etiopia
# 4   1995            Carmem Oliveira       30               Brasil
# Out:
# Quenia      15
# Brasil       6
# Etiopia      6
# Mexicano     1
# Name: Pais-H, dtype: int64

# %%
df['Homens'].value_counts()
# Out:
# Paul Tergat                  5
# Marilson Gomes dos Santos    3
# Robert Kipkoech Cheruiyot    3
# Dawit Admasu                 2
# Edwin Kipsang                2
# Simon Chemwoiywo             2
# James Kipsang                2
# Tesfaye Jifar                1
# Franck Caldeira              1
# Leul Aleme                   1
# Arturo Barrios               1
# Emerson Iser Bem             1
# Tariku Bekele                1
# Stanley Biwott               1
# Belahy Bezabh                1
# Ronaldo da Costa             1
# Name: Homens, dtype: int64

# %%
df['Pais-M'].value_counts()
# Out:
# Quenia                 14
# Brasil                  5
# Etiopia                 4
# Mexico                  2
# Servia e Montenegro     1
# Iugoslavia              1
# Equador                 1
# Name: Pais-M, dtype: int64

# %%
df['Mulheres'].value_counts()
# Out:
# Yimer Wude Ayalew            3
# Lydia Cheromei               3
# Olivera Jevtic               2
# Alice Timbilili              2
# Margaret Okayo               1
# Sandrafelis Tuei             1
# Nancy Kipron                 1
# Hellen Kimaiyo               1
# Maria Del Carmen Diaz        1
# Lucï¿½lia Peres              1
# Maurine Kipchumba            1
# Carmem Oliveira              1
# Roseli Machado               1
# Priscah Jeptoo               1
# Jemima Sumgong               1
# Martha Tenorio               1
# Derartu Tulu                 1
# Pasalia Chepkorir            1
# Flomena Cheyech Daniel       1
# Marizete de Paula Rezende    1
# Maria Zeferina Baldaia       1
# Maria Luisa Servin           1
# Name: Mulheres, dtype: int64

# %%
print(table)
# Out:
# A 22x7 contingency table with counts:
# [[0.5 0.5 0.5 0.5 0.5 2.  0.5]
#  [1.  0.5 0.5 0.5 0.5 0.5 0.5]
#  [0.5 0.5 1.  0.5 0.5 0.5 0.5]
#  [0.5 0.5 0.5 0.5 0.5 1.  0.5]
#  [0.5 0.5 0.5 0.5 0.5 1.  0.5]
#  [0.5 0.5 0.5 0.5 0.5 1.  0.5]
#  [1.  0.5 0.5 0.5 0.5 0.5 0.5]
#  [0.5 0.5 0.5 0.5 0.5 3.  0.5]
#  [0.5 0.5 0.5 0.5 0.5 1.  0.5]
#  [0.5 0.5 0.5 0.5 1.  0.5 0.5]
#  [0.5 0.5 0.5 0.5 1.  0.5 0.5]
#  [1.  0.5 0.5 0.5 0.5 0.5 0.5]
#  [1.  0.5 0.5 0.5 0.5 0.5 0.5]
#  [0.5 1.  0.5 0.5 0.5 0.5 0.5]
#  [0.5 0.5 0.5 0.5 0.5 1.  0.5]
#  [0.5 0.5 0.5 0.5 0.5 1.  0.5]
#  [0.5 0.5 0.5 1.  0.5 0.5 1. ]
#  [0.5 0.5 0.5 0.5 0.5 1.  0.5]
#  [0.5 0.5 0.5 0.5 0.5 1.  0.5]
#  [1.  0.5 0.5 0.5 0.5 0.5 0.5]
#  [0.5 0.5 0.5 0.5 0.5 1.  0.5]
#  [0.5 0.5 3.  0.5 0.5 0.5 0.5]]

# %%
numeric_features = ['Idade','Passagem']
numeric_transformer = Pipeline(steps=[('scaler',StandardScaler())])

# %%
categorical_features = ['Sexo','Embarque', 'Classe']
categorical_transformer = Pipeline(steps=[('oneh',OneHotEncoder(handle_unknown='ignore'))])

# %%
preprocessor = ColumnTransformer( transformers=[
    ('num',numeric_transformer,numeric_features),
    ('cat', categorical_transformer, categorical_features)
])

# %%
clf = Pipeline(steps=[('preprocessor', preprocessor),
                       ('classifier', RandomForestClassifier(n_estimators=100, max_depth=2))])

# %%
X = df.drop('Status',axis=1)

# %%
y = df['Status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('scaler',
#                                                                    StandardScaler(copy=True,
#                                                                                   with_mean=True,
#                                                                                   with_std=True))],
#                                                            verbose=False),
#                                                   ['Idade', 'Passagem']),
#                                                  ('cat',
#                                                   Pipeline(memory=None,
#                                                            steps=[('oneh',
#                                                                    OneHotEncoder(cat...
#                  RandomForestClassifier(bootstrap=True, class_weight=None,
#                                         criterion='gini', max_depth=2,
#                                         max_features='auto',
#                                         max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
print('model score: %.3f'%clf.score(X_test, y_test))
# Out:
# model score: 0.765

# %%
filename = 'RFmodel.sav'
pickle.dump(clf, open(filename, 'wb'))
# Carregando o modelo do disco
loaded_model = pickle.load(open(filename, 'rb'))
# Atribui a variável result o score do modelo
result = loaded_model.score(X_test, y_test)
#Imprime o resultado
print(result)
# Out:
# 0.7653631284916201
