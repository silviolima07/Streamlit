# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from pprint import pprint
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import RandomizedSearchCV
import pickle
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv("dataset.csv")

# %%
df.head(40)
# Out:
#         Status    Classe    Sexo  Idade  Passagem  Embarque
# 0   Sobreviveu  Terceira  mulher    1.0        19  Cherboug
# 1   Sobreviveu  Terceira  mulher    1.0        19  Cherboug
# 2   Sobreviveu  Terceira  mulher    1.0        16  Cherboug
# 3   Sobreviveu   Segunda  mulher    3.0        42  Cherboug
# 4   Sobreviveu  Terceira  mulher    4.0        13  Cherboug
# 5   Sobreviveu  Terceira  mulher    5.0        19  Cherboug
# 6       Morreu  Terceira  mulher    9.0        15  Cherboug
# 7   Sobreviveu  Terceira  mulher   13.0         7  Cherboug
# 8   Sobreviveu  Terceira  mulher   14.0        11  Cherboug
# 9   Sobreviveu   Segunda  mulher   14.0        30  Cherboug
# 10      Morreu  Terceira  mulher   14.5        14  Cherboug
# 11  Sobreviveu  Terceira  mulher   15.0         7  Cherboug
# 12  Sobreviveu  Terceira  mulher   15.0        14  Cherboug
# 13  Sobreviveu  Primeira  mulher   16.0        58  Cherboug
# 14  Sobreviveu   Segunda  mulher   17.0        12  Cherboug
# 15      Morreu  Terceira  mulher   17.0        14  Cherboug
# 16  Sobreviveu  Primeira  mulher   17.0       109  Cherboug
# 17      Morreu  Terceira  mulher   18.0        14  Cherboug
# 18  Sobreviveu  Primeira  mulher   18.0       228  Cherboug
# 19  Sobreviveu  Primeira  mulher   18.0       262  Cherboug
# 20  Sobreviveu  Primeira  mulher   19.0        91  Cherboug
# 21  Sobreviveu  Primeira  mulher   21.0       262  Cherboug
# 22  Sobreviveu   Segunda  mulher   22.0        42  Cherboug
# 23  Sobreviveu  Primeira  mulher   22.0        50  Cherboug
# 24  Sobreviveu   Segunda  mulher   23.0        14  Cherboug
# 25  Sobreviveu  Primeira  mulher   23.0       113  Cherboug
# 26  Sobreviveu  Terceira  mulher   24.0        19  Cherboug
# 27  Sobreviveu  Primeira  mulher   24.0        50  Cherboug
# 28  Sobreviveu  Primeira  mulher   24.0        69  Cherboug
# 29  Sobreviveu  Primeira  mulher   24.0        69  Cherboug
# 30  Sobreviveu  Primeira  mulher   24.0        83  Cherboug
# 31  Sobreviveu   Segunda  mulher   27.0        14  Cherboug
# 32  Sobreviveu   Segunda  mulher   28.0        24  Cherboug
# 33  Sobreviveu  Terceira  mulher   29.0        15  Cherboug
# 34  Sobreviveu  Primeira  mulher   30.0        31  Cherboug
# 35  Sobreviveu  Primeira  mulher   30.0        57  Cherboug
# 36  Sobreviveu  Primeira  mulher   30.0       106  Cherboug
# 37  Sobreviveu  Primeira  mulher   31.0       113  Cherboug
# 38  Sobreviveu  Primeira  mulher   32.0        76  Cherboug
# 39  Sobreviveu  Primeira  mulher   35.0       512  Cherboug

# %%
df.groupby(['Status']).count()
# Out:
#             Classe  Sexo  Idade  Passagem  Embarque
# Status
# Morreu         549   549    549       549       549
# Sobreviveu     342   342    342       342       342

# %%
df.groupby(['Classe'])['Status'].count()
# Out:
# Classe
# Primeira    216
# Segunda     184
# Terceira    491
# Name: Status, dtype: int64

# %%
df.groupby(['Classe', 'Status'])['Status'].count()
# Out:
# Classe    Status
# Primeira  Morreu         80
#           Sobreviveu    136
# Segunda   Morreu         97
#           Sobreviveu     87
# Terceira  Morreu        372
#           Sobreviveu    119
# Name: Status, dtype: int64

# %%
df.groupby(['Sexo', 'Status'])['Status'].count()
# Out:
# Sexo    Status
# homem   Morreu        468
#         Sobreviveu    109
# mulher  Morreu         81
#         Sobreviveu    233
# Name: Status, dtype: int64

# %%
import streamlit as st
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-1aa3dc4fa683> in <module>
# ----> 1 import streamlit as st
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
df.Passagem.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-3a5cf0f06a5b> in <module>
# ----> 1 df.Passagem.str
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
#     177         # http://www.pydanny.com/cached-property.html
#
# ~/.local/lib/python3.6/site-packages/pandas/core/strings.py in __init__(self, data)
#    1915
#    1916     def __init__(self, data):
# -> 1917         self._inferred_dtype = self._validate(data)
#    1918         self._is_categorical = is_categorical_dtype(data)
#    1919
#
# ~/.local/lib/python3.6/site-packages/pandas/core/strings.py in _validate(data)
#    1965
#    1966         if inferred_dtype not in allowed_types:
# -> 1967             raise AttributeError("Can only use .str accessor with string " "values!")
#    1968         return inferred_dtype
#    1969
#
# AttributeError: Can only use .str accessor with string values!
